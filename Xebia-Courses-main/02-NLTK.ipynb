# %%
import nltk
# 4 major uses of nltk
# a. Tokenization
# b. Stopword removal
# c. Stemming
# d. Lemmatization

nltk.download("punkt_tab")
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/ravikanttyagi/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/ravikanttyagi/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/ravikanttyagi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/ravikanttyagi/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# For tokenization
from nltk.tokenize import word_tokenize
# For removing stopwords
from nltk.corpus import stopwords
# For stemming and lemmatization
from nltk.stem import PorterStemmer, WordNetLemmatizer

# %%
text = "I am learning Python programming, it is very helpful!!!<>"
print("Original text:",text)
# Out:
# Original text: I am learning Python programming, it is very helpful!!!<>

# %%
# Step-1: Lowercase
text = text.lower()
print("After Lowercase :",text)
# Out:
# After Lowercase : i am learning python programming, it is very helpful!!!<>

# %%
# Step-2: Tokenization
# text.split()
tokens = word_tokenize(text)
print("Tokens :",tokens)
# Out:
# Tokens : ['i', 'am', 'learning', 'python', 'programming', ',', 'it', 'is', 'very', 'helpful', '!', '!', '!', '<', '>']

# %%
# Step-3: Remove punctuations
import string
punc = string.punctuation
print(punc)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
punctuation_filter = [word for word in tokens if word not in punc]
print("Removed Punctuations:",punctuation_filter)
# Out:
# Removed Punctuations: ['i', 'am', 'learning', 'python', 'programming', 'it', 'is', 'very', 'helpful']

# %%
# Step-4: Remove stopwords
# print(stopwords.words("english"))
eng_stopwords = stopwords.words("english")
filtered_tokens = [word for word in punctuation_filter if word not in eng_stopwords]
print("Removed stopwords:",filtered_tokens)
# Out:
# Removed stopwords: ['learning', 'python', 'programming', 'helpful']

# %%
# Step-5: Stemming & Lemmatization
stem = PorterStemmer()
stem.stem("bought")
# Out:
# 'bought'

# %%
wnet = WordNetLemmatizer()
print("Playing :", wnet.lemmatize("playing","v"))
print("Flying :",wnet.lemmatize("flying","v"))
print("Went :",wnet.lemmatize("went","v"))
print("Bought :",wnet.lemmatize("bought","v"))
# Out:
# Playing : play
# Flying : fly
# Went : go
# Bought : buy

# %%
lemmatized_words = []
for word in filtered_tokens:
    lemmatized_words.append(wnet.lemmatize(word,"v"))

print("Lemmatization:",lemmatized_words)
# Out:
# Lemmatization: ['learn', 'python', 'program', 'helpful']

# %%
cleaned_text = " ".join(lemmatized_words)
print("Cleaned Text:",cleaned_text)
# Out:
# Cleaned Text: learn python program helpful
